# %% [raw]
# ---
# title: "03wk-1"
# author: "최규빈"
# date: "09/19/2022"
# categories:
#   - matplotlib
# ---

# %% [markdown]
# > 라인플랏, 산점도, 여러 그림 그리기, fig와 axes의 이해

# %% [markdown]
# # 강의영상

# %% [markdown]
# <https://youtube.com/playlist?list=PLQqh36zP38-xX1bzyd7pHlAlCcX3mzja2>

# %% [markdown]
# # 오늘 배울 내용?

# %% [markdown]
# `-` 라인플랏과 산점도를 그리는 방법
#
# `-` 여러 그림그리기 (한 플랏에 그림을 겹치는 방법, subplot을 그리는 방법)
#
# `-` fig, axes의 개념이해 (객체지향적 프로그래밍)

# %% [markdown]
# # imports

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Line plot

# %% [markdown]
# ## 기본플랏

# %% [markdown]
# `-` 예시1

# %%
x=[1,2,3,4]
y=[1,2,4,3]

# %%
plt.plot(x,y)

# %% [markdown]
# ## 모양변경

# %% [markdown]
# `-` 예시1

# %%
plt.plot(x,y,'--')

# %% [markdown]
# `-` 예시2

# %%
plt.plot(x,y,':')

# %% [markdown]
# `-` 예시3

# %%
plt.plot(x,y,'-.')

# %% [markdown]
# ## 색상변경

# %% [markdown]
# `-` 예시1

# %%
plt.plot(x,y,'r')

# %% [markdown]
# `-` 예시2

# %%
plt.plot(x,y,'k')

# %% [markdown]
# ## 모양 + 색상변경

# %% [markdown]
# `-` 예시1

# %%
plt.plot(x,y,'--r')

# %% [markdown]
# `-` 예시2: 순서변경 가능

# %%
plt.plot(x,y,'r--')

# %% [markdown]
# ## 원리?

# %% [markdown]
# `-` `r--`등의 옵션은 Markers + Line Styles + Colors 의 조합으로 표현가능

# %% [markdown]
# ref: <https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html>

# %% [markdown]
# - `--r`: 점선(dashed)스타일 + 빨간색
# - `r--`: 빨간색 + 점선(dashed)스타일
# - `:k`: 점선(dotted)스타일 + 검은색
# - `k:`: 검은색 + 점선(dotted)스타일

# %% [markdown]
# `-` 우선 Marker를 무시하면 Line Styles + Color로 표현가능한 조합은 $4\times 8=32$ 개

# %% [markdown]
# **(Line Styles)** 모두 4개

# %% [markdown]
# | character | description|
# |:-:|:-:|
# | '-' | solid line style |
# | '--' | dashed line style |
# | '-.' | dash-dot line style |
# | ':' | dotted line style|

# %% [markdown]
# **(Color)** 모두 8개

# %% [markdown]
# |character|color|
# |:-:|:-:|
# |'b'| blue|
# |'g'|green|
# |'r'|red|
# |'c'|cyan|
# |'m'|magenta|
# |'y'|yellow|
# |'k'|black|
# |'w'|white|

# %% [markdown]
# `-` 예시1

# %%
plt.plot(x,y,'--m')

# %% [markdown]
# `-` 예시2

# %%
plt.plot(x,y,'-.c')

# %% [markdown]
# `-` 예시3: line style + color 조합으로 사용하든 color + line style 조합으로 사용하든 상관없음

# %%
plt.plot(x,y,'-.c')

# %%
plt.plot(x,y,'c-.')

# %% [markdown]
# `-` 예시4: line style을 중복으로 사용하거나 color를 중복으로 쓸 수 는 없다.

# %%
plt.plot(x,y,'--:')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_105674/54727817.py in <module>
# ----> 1 plt.plot(x,y,'--:')
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767     return gca().plot(
#    2768         *args, scalex=scalex, scaley=scaley,
# -> 2769         **({"data": data} if data is not None else {}), **kwargs)
#    2770
#    2771
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1633         """
#    1634         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1635         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1636         for line in lines:
#    1637             self.add_line(line)
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     447             # xy is tup with fmt stripped (could still be (y,) only)
#     448             *xy, fmt = tup
# --> 449             linestyle, marker, color = _process_plot_format(fmt)
#     450         elif len(tup) == 3:
#     451             raise ValueError('third arg must be a format string')
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/axes/_base.py in _process_plot_format(fmt)
#     171             if linestyle is not None:
#     172                 raise ValueError(
# --> 173                     'Illegal format string "%s"; two linestyle symbols' % fmt)
#     174             linestyle = fmt[i:i+2]
#     175             i += 2
#
# ValueError: Illegal format string "--:"; two linestyle symbols

# %%
plt.plot(x,y,'rb')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_105674/3007505469.py in <module>
# ----> 1 plt.plot(x,y,'rb')
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767     return gca().plot(
#    2768         *args, scalex=scalex, scaley=scaley,
# -> 2769         **({"data": data} if data is not None else {}), **kwargs)
#    2770
#    2771
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1633         """
#    1634         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1635         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1636         for line in lines:
#    1637             self.add_line(line)
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     447             # xy is tup with fmt stripped (could still be (y,) only)
#     448             *xy, fmt = tup
# --> 449             linestyle, marker, color = _process_plot_format(fmt)
#     450         elif len(tup) == 3:
#     451             raise ValueError('third arg must be a format string')
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/axes/_base.py in _process_plot_format(fmt)
#     189             if color is not None:
#     190                 raise ValueError(
# --> 191                     'Illegal format string "%s"; two color symbols' % fmt)
#     192             color = c
#     193             i += 1
#
# ValueError: Illegal format string "rb"; two color symbols

# %% [markdown]
# `-` 예시5: 색이 사실 8개만 있는건 아니다.

# %% [markdown]
# ref: <https://matplotlib.org/2.0.2/examples/color/named_colors.html>

# %%
plt.plot(x,y,'--',color='lime')

# %% [markdown]
# `-` 예시6: 색을 바꾸려면 Hex코드를 밖아 넣는 방법이 젤 깔끔함

# %% [markdown]
# ref: <https://htmlcolorcodes.com/>

# %%
plt.plot(x,y,color='#277E41')

# %% [markdown]
# `-` 예시7: 당연히 라인스타일도 4개만 있진 않겠지

# %% [markdown]
# ref: <https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html>

# %%
plt.plot(x,y,linestyle='dashed')

# %%
plt.plot(x,y,linestyle=(0, (20, 5)))

# %% [markdown]
# # Scatter plot

# %% [markdown]
# ## 원리

# %% [markdown]
# `-` 그냥 마커를 설정하면 끝!

# %% [markdown]
# ref: <https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html>

# %% [markdown]
# |character | description|
# |:-:|:-:|
# |'.'| point marker|
# |','|pixel marker|
# |'o'|circle marker|
# |'v'| triangle_down marker |
# |'^'|triangle_up marker|
# |'<'|triangle_left marker|
# |'>'|triangle_right marker|
# |'1'|tri_down marker|
# |'2'|tri_up marker|
# |'3'|tri_left marker|
# |'4'|tri_right marker|
# |'8'|octagon marker|
# |'s'|square marker|
# |'p'|pentagon marker|
# |'P'|plus (filled) marker|
# |'*'|star marker|
# |'h'|hexagon1 marker|
# |'H'|hexagon2 marker|
# |'+'|plus marker|
# |'x'|x marker|
# |'X'|x (filled) marker|
# |'D'|diamond marker|
# |'d'|thin_diamond marker|
# |'\|'|vline marker|
# |'_'|hline marker|

# %%
plt.plot(x,y,'o')

# %% [markdown]
# ## 기본플랏

# %% [markdown]
# `-` 예시1

# %%
plt.plot(x,y,'.')

# %% [markdown]
# `-` 예시2

# %%
plt.plot(x,y,'x')

# %% [markdown]
# ## 색깔변경

# %% [markdown]
# `-` 예시1

# %%
plt.plot(x,y,'or')

# %% [markdown]
# `-` 예시2

# %%
plt.plot(x,y,'db')

# %% [markdown]
# `-` 예시3

# %%
plt.plot(x,y,'bx')

# %% [markdown]
# ## dot-connected plot

# %% [markdown]
# `-` 예시1: 마커와 라인스타일을 동시에 사용하면 dot-connected plot이 된다.

# %%
plt.plot(x,y,'o-')

# %% [markdown]
# `-` 예시2: 당연히 색도 적용가능함

# %%
plt.plot(x,y,'o--r')

# %% [markdown]
# `-` 예시3: 서로 순서를 바꿔도 상관없다.

# %%
plt.plot(x,y,'ro--')

# %% [markdown]
# # 여러 그림 그리기

# %% [markdown]
# ## 겹쳐그리기

# %% [markdown]
# `-` 예시1

# %%
x = np.arange(-5,5,0.1)
ϵ = np.random.randn(100) 
y = 2*x + ϵ

# %%
plt.plot(x,y,'.b')
plt.plot(x,2*x,'r')

# %% [markdown]
# ## 따로그리기 (subplot) // 외우세요 이거

# %% [markdown]
# `-` 예시1

# %%
fig, axs = plt.subplots(2) 
axs[0].plot(x,y,'.b')
axs[1].plot(x,2*x,'r')

# %% [markdown]
# `-` 예시2

# %%
fig, axs = plt.subplots(2,2)
axs[0,0].plot(x,2*x,'--b')
axs[0,1].plot(x,ϵ,'.r')
axs[1,0].plot(x,y,'.r')
axs[1,1].plot(x,y,'.r')
axs[1,1].plot(x,2*x,'-b')

# %% [markdown]
# # fig와 axes의 이해 : matplotlib으로 어렵게 그림을 그리는 방법

# %% [markdown]
# ### 예제1

# %% [markdown]
# `-` 목표: plt.plot()을 이용하지 않고 아래의 그림을 그려보자.

# %%
plt.plot([1,2,3,4],[1,2,4,3],'or--')

# %% [markdown]
# `-` 구조: axis $\subset$ axes $\subset$ figure

# %% [markdown]
# ref: https://matplotlib.org/stable/gallery/showcase/anatomy.html#sphx-glr-gallery-showcase-anatomy-py

# %% [markdown]
# ![](https://matplotlib.org/stable/_images/sphx_glr_anatomy_001.png)

# %% [markdown]
# `-` 전략: `Fig`을 만들고 (도화지를 준비) $\to$ `axes`를 만들고 (네모틀) $\to$ `axes`에 그림을 그린다.

# %% [markdown]
# `-` 그림객체를 생성한다.

# %%
fig = plt.figure()

# %%
fig # 지금은 아무것도 없다.

# %% [markdown]
# `-` 그림객체에는 여러 인스턴스 + 함수가 있는데 그중에서 axes도 있다. (그런데 그와중에 plot method는 없다)

# %%
fig.axes # 비어있는 리스트
# Out:
# []

# %% [markdown]
# `-` axes 추가

# %%
fig.add_axes([0,0,1,1]) # (0,0)의 위치에 (1,1)인 액시즈(=네모틀)을 만들어라.
# Out:
# <Axes:>

# %%
fig.axes
# Out:
# [<Axes:>]

# %%
fig # 도화지안에 네모틀이 들어가 있다.

# %% [markdown]
# `-` 첫번째 액시즈를 ax1로 받음 (원래 axes1이어야하는데 그냥 편의상)

# %%
ax1 = fig.axes[0]

# %%
id(fig.axes[0]),id(ax1)
# Out:
# (139891930961872, 139891930961872)

# %% [markdown]
# `-` 잠깐만! (fig 오브젝트와 ax1 오브젝트는 포함관계에 있다)

# %%
id(fig.axes[0]),id(ax1)
# Out:
# (139891930961872, 139891930961872)

# %% [markdown]
# `-` 또 잠깐만! (fig 오브젝트에는 plot이 없지만 ax1 오브젝트에는 plot이 있다)

# %%
set(dir(fig)) & {'plot'}
# Out:
# set()

# %%
set(dir(ax1)) & {'plot'}
# Out:
# {'plot'}

# %% [markdown]
# `-` ax1.plot()을 사용하여 그림을 그려보자.

# %%
ax1.plot([1,2,3,4],[1,2,4,3],'--or')

# %%
fig

# %% [markdown]
# ## 예제2: 예제1의 응용

# %% [markdown]
# `-` 예제1상황

# %%
fig

# %% [markdown]
# `-` 여기서 축을 하나 더 추가할거에요

# %%
fig.axes
# Out:
# [<Axes:>]

# %%
fig.add_axes([1,1,1,1])
# Out:
# <Axes:>

# %%
fig.axes
# Out:
# [<Axes:>, <Axes:>]

# %%
fig

# %%
ax1,ax2 = fig.axes

# %% [markdown]
# `-` ax2에 파란선으로 그림을 그리자.

# %%
ax2.plot([1,2,3,4],[1,2,4,3],'--ob')

# %%
fig

# %% [markdown]
# ## 예제3: 더 응용! (미니맵)

# %% [markdown]
# `-` 지금 상황

# %%
fig

# %% [markdown]
# `-` 액시즈를 하나 더 추가

# %%
fig.add_axes([0.65,0.1,0.3,0.3])
# Out:
# <Axes:>

# %%
fig

# %%
fig.axes[-1].plot([1,2,3,4],[1,2,4,3],'xr')

# %%
fig

# %% [markdown]
# ## 예제4: 재해석1

# %% [markdown]
# (ver1)

# %%
plt.plot([1,2,3,4],[1,2,4,3])

# %% [markdown]
# (ver2)

# %% [markdown]
# ver1은 사실 아래가 연속적으로 실행된 축약구문임
# ```python
# fig = plt.figure()
# fig.add_axes([?,?,?,?])
# ax1 = fig.axes[0]
# ax1.plot([1,2,3,4],[1,2,4,3])
# fig
# ```

# %% [markdown]
# ## 예제5: 재해석2

# %% [markdown]
# `-` 아래의 코드도 재해석하자.

# %%
fig, axs = plt.subplots(2,2)

# %%
fig, axs = plt.subplots(2,2)
axs[0,0].plot([1,2,3,4],[1,2,4,3],'.')
axs[0,1].plot([1,2,3,4],[1,2,4,3],'--r')
axs[1,0].plot([1,2,3,4],[1,2,4,3],'o--')
axs[1,1].plot([1,2,3,4],[1,2,4,3],'o--',color='lime')

# %% [markdown]
# `-` `fig, axs = plt.subplots(2,2)`의 축약버전을 이해하면된다.

# %% [markdown]
# (ver1)

# %%
fig, axs = plt.subplots(2,2)

# %% [markdown]
# (ver2)

# %% [markdown]
# ver1은 사실 아래의 축약!

# %% [markdown]
# ```python
# fig = plt.figure()
# fig.add_axes([?,?,?,?])
# fig.add_axes([?,?,?,?])
# fig.add_axes([?,?,?,?])
# fig.add_axes([?,?,?,?])
# ax1,ax2,ax3,ax4 = fig.axes
# axs = np.array(((ax1,ax2),(ax3,ax4)))
# ```

# %% [markdown]
# (ver3)

# %% [markdown]
# ver1은 아래와 같이 표현할 수도 있다.

# %%
fig = plt.figure()
axs = fig.subplots(2,2)

# %% [markdown]
# # HW

# %% [markdown]
# **제출: `이름(학번).ipynb`, `이름(학번).html` 형태로 정리하여 2개의 파일을 제출할 것 (작성방법 모르면 아래영상참고할것)**
# - 즉 주피터노트북파일과 html파일을 모두 제출할 것

# %% [markdown]
# <https://youtube.com/playlist?list=PLQqh36zP38-x3HQLeyrS7GLh70Dv_54Yg>

# %% [markdown]
# - 영상1: 코랩으로 실습하는 경우
# - 영상2: local 아나콘다로 실습하는 경우

# %% [markdown]
# ### `1`. 아래와 같은 그림을 그려라.

# %%
x,y = [1,2,3,4], [1,2,4,3]

# %%
#

# %% [markdown]
# ### `2`. 아래와 같은 그림을 그려라.

# %%
x,y = [1,2,3,4], [1,2,1,1]

# %%
#

# %% [markdown]
# ### `3`. 아래와 같은 그림을 그려라.

# %%
x = np.arange(-5,5,0.1)
y1 = np.sin(x)
y2 = np.sin(2*x) + 2
y3 = np.sin(4*x) + 4 
y4 = np.sin(8*x) + 6

# %%
#
